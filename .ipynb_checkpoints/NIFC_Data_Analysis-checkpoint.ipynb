# %%
import geopandas as gp
import pandas as pd

# %%
df = pd.read_csv("Wildland_Fire_Incident_Locations.csv")
# Out:
# /var/folders/dx/sc89948n7r9d_y3ms23yc8c40000gn/T/ipykernel_97208/1734720274.py:1: DtypeWarning: Columns (7,8,17,35,64,67,88,89,93,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Wildland_Fire_Incident_Locations.csv")

# %%
columns = list(df.columns)
redcols = []
for i in columns:
    m = df[i].isna().sum()
    print(i, '                ', m)
    if m >0.5*df.shape[0]:
        redcols.append(i)
# Out:
# X                  0
# Y                  0
# OBJECTID                  0
# SourceOID                  0
# ABCDMisc                  237386
# ADSPermissionState                  0
# CalculatedAcres                  245041
# ContainmentDateTime                  98989
# ControlDateTime                  113776
# CreatedBySystem                  0
# IncidentSize                  75762
# DiscoveryAcres                  64508
# DispatchCenterID                  37378
# EstimatedCostToDate                  235668
# FinalAcres                  232228
# FinalFireReportApprovedByTitle                  250391
# FinalFireReportApprovedByUnit                  247775
# FinalFireReportApprovedDate                  217087
# FireBehaviorGeneral                  234747
# FireBehaviorGeneral1                  243220
# FireBehaviorGeneral2                  244393
# FireBehaviorGeneral3                  246534
# FireCause                  30649
# FireCauseGeneral                  196147
# FireCauseSpecific                  235689
# FireCode                  122587
# FireDepartmentID                  239973
# FireDiscoveryDateTime                  0
# FireMgmtComplexity                  228918
# FireOutDateTime                  105444
# FireStrategyConfinePercent                  243100
# FireStrategyFullSuppPercent                  240904
# FireStrategyMonitorPercent                  242991
# FireStrategyPointZonePercent                  243366
# FSJobCode                  183138
# FSOverrideCode                  183787
# GACC                  59
# ICS209ReportDateTime                  237374
# ICS209ReportForTimePeriodFrom                  237699
# ICS209ReportForTimePeriodTo                  237718
# ICS209ReportStatus                  236607
# IncidentManagementOrganization                  238182
# IncidentName                  9
# IncidentShortDescription                  240877
# IncidentTypeCategory                  0
# IncidentTypeKind                  0
# InitialLatitude                  66632
# InitialLongitude                  66632
# InitialResponseAcres                  163051
# InitialResponseDateTime                  219984
# IrwinID                  0
# IsFireCauseInvestigated                  239088
# IsFireCodeRequested                  0
# IsFSAssisted                  57957
# IsMultiJurisdictional                  67882
# IsReimbursable                  64237
# IsTrespass                  64929
# IsUnifiedCommand                  240253
# LocalIncidentIdentifier                  0
# PercentContained                  229265
# PercentPerimeterToBeContained                  241327
# POOCity                  244686
# POOCounty                  161
# POODispatchCenterID                  77614
# POOFips                  168
# POOJurisdictionalAgency                  144132
# POOJurisdictionalUnit                  89101
# POOJurisdictionalUnitParentUnit                  250388
# POOLandownerCategory                  67746
# POOLandownerKind                  66933
# POOLegalDescPrincipalMeridian                  248096
# POOLegalDescQtr                  249343
# POOLegalDescQtrQtr                  249420
# POOLegalDescRange                  248144
# POOLegalDescSection                  248142
# POOLegalDescTownship                  248144
# POOPredictiveServiceAreaID                  29336
# POOProtectingAgency                  48924
# POOProtectingUnit                  0
# POOState                  0
# PredominantFuelGroup                  216077
# PredominantFuelModel                  216674
# PrimaryFuelModel                  234300
# SecondaryFuelModel                  243921
# TotalIncidentPersonnel                  239185
# UniqueFireIdentifier                  0
# WFDSSDecisionStatus                  1349
# EstimatedFinalCost                  248556
# OrganizationalAssessment                  248441
# StrategicDecisionPublishDate                  248558
# CreatedOnDateTime_dt                  0
# ModifiedOnDateTime_dt                  0
# IsCpxChild                  0
# CpxName                  249742
# CpxID                  249742
# SourceGlobalID                  0
# GlobalID                  0

# %%
df.drop(columns = redcols, inplace=True)
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'SourceOID', 'ADSPermissionState',
#        'ContainmentDateTime', 'ControlDateTime', 'CreatedBySystem',
#        'IncidentSize', 'DiscoveryAcres', 'DispatchCenterID', 'FireCause',
#        'FireCode', 'FireDiscoveryDateTime', 'FireOutDateTime', 'GACC',
#        'IncidentName', 'IncidentTypeCategory', 'IncidentTypeKind',
#        'InitialLatitude', 'InitialLongitude', 'IrwinID', 'IsFireCodeRequested',
#        'IsFSAssisted', 'IsMultiJurisdictional', 'IsReimbursable', 'IsTrespass',
#        'LocalIncidentIdentifier', 'POOCounty', 'POODispatchCenterID',
#        'POOFips', 'POOJurisdictionalUnit', 'POOLandownerCategory',
#        'POOLandownerKind', 'POOPredictiveServiceAreaID', 'POOProtectingAgency',
#        'POOProtectingUnit', 'POOState', 'UniqueFireIdentifier',
#        'WFDSSDecisionStatus', 'CreatedOnDateTime_dt', 'ModifiedOnDateTime_dt',
#        'IsCpxChild', 'SourceGlobalID', 'GlobalID'],
#       dtype='object')

# %%
from shapely.geometry import Point
geometry = [Point(xy) for xy in zip(df['X'], df['Y'])]
gdf = gp.GeoDataFrame(df, geometry=geometry)
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=.05)
# Out:
# <AxesSubplot: >

# %%
df.IncidentSize
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 250386    20.00
# 250387     0.76
# 250388    42.70
# 250389     1.00
# 250390    20.00
# Name: IncidentSize, Length: 250391, dtype: float64
